# %% [markdown]
# # Reliance Stock Market Data Analysis 2020
#
# As we all our known with the word stock market in which stocks of the commodities, currencies & many more are traded/exchanged. I personally have a great interest in Stock market so i thought of working on it. I took this dataset from kaggle. I chose Reliance stocks for analysing.this dataset consist of the reliance stocks highs and lows, opening price, previous closing price. In this dataset i will be analysing about their stocks by using pandas for cleaning and preparation and also i am going to use matplotlib and seaborn tools for visualizing of data.

# %% [markdown]
# ## Data Preparation and Cleaning
#
# As the dataset contains large amount of data. It is needed to see if their is any missing value in it before working on it so for that i will be using different libraries for further processing, preparation and cleaning of data.

# %% [markdown]
# Before working further lets import all the libraries that i am going to use during analysing.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Lets first read the data by using read_csv function and convert this data into a dataframe.

# %%
reliance_df = pd.read_csv('RELIANCE_2020.csv')
reliance_df
# Out:
#            Date    Symbol Series  Prev Close     Open     High      Low  \
# 0    01/01/2020  RELIANCE     EQ     1514.05  1518.00  1527.10  1505.50
# 1    02/01/2020  RELIANCE     EQ     1509.60  1512.00  1540.95  1512.00
# 2    03/01/2020  RELIANCE     EQ     1535.30  1533.00  1541.65  1523.00
# 3    06/01/2020  RELIANCE     EQ     1537.15  1520.00  1527.90  1498.00
# 4    07/01/2020  RELIANCE     EQ     1501.50  1519.00  1534.50  1513.50
# ..          ...       ...    ...         ...      ...      ...      ...
# 247  24/12/2020  RELIANCE     EQ     1943.85  1947.00  1998.80  1945.90
# 248  28/12/2020  RELIANCE     EQ     1994.15  2006.70  2018.00  1995.30
# 249  29/12/2020  RELIANCE     EQ     2003.30  2009.00  2012.30  1982.55
# 250  30/12/2020  RELIANCE     EQ     1990.05  1995.25  2007.20  1975.55
# 251  31/12/2020  RELIANCE     EQ     1995.50  1993.50  2011.90  1978.60
#
#         Last    Close     VWAP    Volume      Turnover  Trades  \
# ...

# %%
#Lets check no. of rows and col in dataset

reliance_df.shape
# Out:
# (252, 15)

# %% [markdown]
# So it seems their are 15 col and 252 rows in reliance dataframe.
#
# Now lets check the basic information about the data.

# %%
#info() function gives overall information about the data.

reliance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                252 non-null    object
#  1   Symbol              252 non-null    object
#  2   Series              252 non-null    object
#  3   Prev Close          252 non-null    float64
#  4   Open                252 non-null    float64
#  5   High                252 non-null    float64
#  6   Low                 252 non-null    float64
#  7   Last                252 non-null    float64
#  8   Close               252 non-null    float64
#  9   VWAP                252 non-null    float64
#  10  Volume              252 non-null    int64
#  11  Turnover            252 non-null    float64
#  12  Trades              252 non-null    int64
#  13  Deliverable Volume  252 non-null    int64
#  14  %Deliverble         252 non-null    float64
# ...

# %%
reliance_df.Date
# Out:
# 0      01/01/2020
# 1      02/01/2020
# 2      03/01/2020
# 3      06/01/2020
# 4      07/01/2020
#           ...
# 247    24/12/2020
# 248    28/12/2020
# 249    29/12/2020
# 250    30/12/2020
# 251    31/12/2020
# Name: Date, Length: 252, dtype: object

# %% [markdown]
# The Date column has datatype object lets change it to datetime datatype.

# %%
reliance_df['Date'] = pd.to_datetime(reliance_df.Date)

# %%
reliance_df.Date
# Out:
# 0     2020-01-01
# 1     2020-02-01
# 2     2020-03-01
# 3     2020-06-01
# 4     2020-07-01
#          ...
# 247   2020-12-24
# 248   2020-12-28
# 249   2020-12-29
# 250   2020-12-30
# 251   2020-12-31
# Name: Date, Length: 252, dtype: datetime64[ns]

# %% [markdown]
# The date column datatype has changed now its easy to access it. lets make different parts of Date column in different columns.

# %%
reliance_df['month'] = pd.DatetimeIndex(reliance_df.Date).month
reliance_df['day'] = pd.DatetimeIndex(reliance_df.Date).day
reliance_df['weekday'] = pd.DatetimeIndex(reliance_df.Date).weekday
reliance_df
# Out:
#           Date    Symbol Series  Prev Close     Open     High      Low  \
# 0   2020-01-01  RELIANCE     EQ     1514.05  1518.00  1527.10  1505.50
# 1   2020-02-01  RELIANCE     EQ     1509.60  1512.00  1540.95  1512.00
# 2   2020-03-01  RELIANCE     EQ     1535.30  1533.00  1541.65  1523.00
# 3   2020-06-01  RELIANCE     EQ     1537.15  1520.00  1527.90  1498.00
# 4   2020-07-01  RELIANCE     EQ     1501.50  1519.00  1534.50  1513.50
# ..         ...       ...    ...         ...      ...      ...      ...
# 247 2020-12-24  RELIANCE     EQ     1943.85  1947.00  1998.80  1945.90
# 248 2020-12-28  RELIANCE     EQ     1994.15  2006.70  2018.00  1995.30
# 249 2020-12-29  RELIANCE     EQ     2003.30  2009.00  2012.30  1982.55
# 250 2020-12-30  RELIANCE     EQ     1990.05  1995.25  2007.20  1975.55
# 251 2020-12-31  RELIANCE     EQ     1995.50  1993.50  2011.90  1978.60
#
#         Last    Close     VWAP    Volume      Turnover  Trades  \
# ...

# %% [markdown]
# We have added month, day, weekday columns in dataframe.

# %%
# columns function gives all the columns in the data.

reliance_df.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble', 'month', 'day', 'weekday'],
#       dtype='object')

# %%
#lets just check some top 10 values

reliance_df.head(10)
# Out:
#         Date    Symbol Series  Prev Close     Open     High      Low     Last  \
# 0 2020-01-01  RELIANCE     EQ     1514.05  1518.00  1527.10  1505.50  1511.80
# 1 2020-02-01  RELIANCE     EQ     1509.60  1512.00  1540.95  1512.00  1534.10
# 2 2020-03-01  RELIANCE     EQ     1535.30  1533.00  1541.65  1523.00  1536.00
# 3 2020-06-01  RELIANCE     EQ     1537.15  1520.00  1527.90  1498.00  1499.90
# 4 2020-07-01  RELIANCE     EQ     1501.50  1519.00  1534.50  1513.50  1526.95
# 5 2020-08-01  RELIANCE     EQ     1524.60  1515.00  1534.45  1510.00  1514.00
# 6 2020-09-01  RELIANCE     EQ     1513.15  1538.60  1550.00  1531.25  1549.50
# 7 2020-10-01  RELIANCE     EQ     1548.00  1551.90  1557.95  1539.65  1546.85
# 8 2020-01-13  RELIANCE     EQ     1547.65  1545.05  1558.70  1538.40  1539.85
# 9 2020-01-14  RELIANCE     EQ     1543.70  1540.00  1550.00  1521.85  1529.10
#
#      Close     VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# ...

# %% [markdown]
# From above we dont require some columns so lets just delete them. We dont require symbol and series column so lets just delete them.

# %%
reliance_df.drop(['Symbol', 'Series'], axis=1)
# Out:
#           Date  Prev Close     Open     High      Low     Last    Close  \
# 0   2020-01-01     1514.05  1518.00  1527.10  1505.50  1511.80  1509.60
# 1   2020-02-01     1509.60  1512.00  1540.95  1512.00  1534.10  1535.30
# 2   2020-03-01     1535.30  1533.00  1541.65  1523.00  1536.00  1537.15
# 3   2020-06-01     1537.15  1520.00  1527.90  1498.00  1499.90  1501.50
# 4   2020-07-01     1501.50  1519.00  1534.50  1513.50  1526.95  1524.60
# ..         ...         ...      ...      ...      ...      ...      ...
# 247 2020-12-24     1943.85  1947.00  1998.80  1945.90  1992.95  1994.15
# 248 2020-12-28     1994.15  2006.70  2018.00  1995.30  2002.00  2003.30
# 249 2020-12-29     2003.30  2009.00  2012.30  1982.55  1987.00  1990.05
# 250 2020-12-30     1990.05  1995.25  2007.20  1975.55  1994.35  1995.50
# 251 2020-12-31     1995.50  1993.50  2011.90  1978.60  1981.80  1985.30
#
#         VWAP    Volume      Turnover  Trades  Deliverable Volume  %Deliverble  \
# ...

# %%
reliance_df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count   252.000000   252.000000   252.000000   252.000000   252.000000
# mean   1741.532143  1747.009524  1772.215079  1718.632143  1744.380357
# std     366.222113   369.018578   366.504492   367.300000   366.082495
# min     884.050000   916.200000   950.000000   875.650000   891.000000
# 25%    1460.337500  1456.787500  1478.687500  1443.775000  1459.875000
# 50%    1774.125000  1792.400000  1819.575000  1777.125000  1791.700000
# 75%    2078.112500  2084.250000  2102.587500  2041.962500  2077.000000
# max    2324.550000  2325.000000  2369.350000  2310.550000  2324.900000
#
#              Close         VWAP        Volume      Turnover        Trades  \
# count   252.000000   252.000000  2.520000e+02  2.520000e+02  2.520000e+02
# mean   1743.402183  1745.697579  1.775977e+07  3.078627e+15  3.944233e+05
# std     366.259063   367.356123  1.072495e+07  2.011815e+15  2.127432e+05
# ...

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# In this, we'll do some visualization using some plots, charts in order to make some exploratory analysis.

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ### 1. What was the maximum highest value of Reliance stock in the year 2020 ?

# %%
reliance_df_high = reliance_df.sort_values(by= 'High', ascending=False).head(10)
reliance_df_high
# Out:
#           Date    Symbol Series  Prev Close     Open     High      Low  \
# 178 2020-09-16  RELIANCE     EQ     2318.85  2320.00  2369.35  2310.55
# 176 2020-09-14  RELIANCE     EQ     2319.75  2325.00  2360.00  2282.00
# 174 2020-10-09  RELIANCE     EQ     2161.35  2183.10  2344.95  2175.35
# 175 2020-11-09  RELIANCE     EQ     2314.00  2312.00  2337.85  2287.10
# 181 2020-09-21  RELIANCE     EQ     2305.70  2300.00  2336.00  2247.35
# 179 2020-09-17  RELIANCE     EQ     2324.55  2320.00  2333.70  2291.85
# 177 2020-09-15  RELIANCE     EQ     2302.55  2311.95  2325.75  2288.15
# 180 2020-09-18  RELIANCE     EQ     2298.75  2314.25  2319.45  2276.55
# 192 2020-07-10  RELIANCE     EQ     2210.35  2235.00  2309.00  2220.00
# 197 2020-10-14  RELIANCE     EQ     2280.70  2278.90  2304.00  2268.50
#
#         Last    Close     VWAP    Volume      Turnover   Trades  \
# 178  2324.90  2324.55  2339.46  15669133  3.665740e+15   321651
# ...

# %%
sns.barplot(reliance_df.month, reliance_df.High);
# Out:
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# It seems that in the month of september and october the stocks value was high which was 2369.

# %% [markdown]
# ### 2. What was the lowest close in the year 2020 of the stocks ?

# %%
reliance_df_close = reliance_df.sort_values(by='Prev Close', ascending=True).head(10)
reliance_df_close
# Out:
#          Date    Symbol Series  Prev Close     Open     High      Low  \
# 58 2020-03-24  RELIANCE     EQ      884.05   930.00   970.00   895.80
# 56 2020-03-20  RELIANCE     EQ      917.70   939.50  1034.90   930.00
# 59 2020-03-25  RELIANCE     EQ      943.40   963.80  1151.55   963.25
# 55 2020-03-19  RELIANCE     EQ      968.50   920.10   967.00   892.20
# 54 2020-03-18  RELIANCE     EQ     1008.00  1025.30  1035.90   961.00
# 53 2020-03-17  RELIANCE     EQ     1015.70  1047.25  1060.00  1003.20
# 57 2020-03-23  RELIANCE     EQ     1017.95   916.20   950.00   875.65
# 63 2020-03-31  RELIANCE     EQ     1030.45  1073.95  1129.80  1048.00
# 51 2020-03-13  RELIANCE     EQ     1063.00   998.00  1140.00   942.40
# 62 2020-03-30  RELIANCE     EQ     1065.60  1040.60  1074.80  1020.00
#
#        Last    Close     VWAP    Volume      Turnover  Trades  \
# 58   946.00   943.40   934.85  20919322  1.955650e+15  590891
# 56  1028.00  1017.95   983.98  28967526  2.850340e+15  589033
# ...

# %%
sns.histplot(reliance_df['Prev Close']);

# %% [markdown]
# ### 3. What was the turnover in the month of september ?

# %%
# lets extract september month data
reliance_df_september = reliance_df[reliance_df.month == 9]

# data of september month turnover
reliance_df_turnoversept = reliance_df_september['Turnover']

# sum of turnover in september
reliance_df_turntotal = reliance_df_turnoversept.sum()
reliance_df_turntotal
# Out:
# 6.815627e+16

# %%
plt.title('Turnover in September')
plt.plot(reliance_df_turnoversept);

# %% [markdown]
# ### 4.  What was the count of trade happened in Reliance Shares 2020 ?

# %%
reliance_df_trade = reliance_df.Trades
reliance_df_tradecount = reliance_df_trade.sum()
reliance_df_tradecount
# Out:
# 99394684

# %%
sns.barplot(reliance_df.month, reliance_df.Trades);
# Out:
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# It seems the trade during the month of april, july were high as compared to other months.

# %% [markdown]
# ### 5. What was the volume of trades in each month ?

# %%
plt.title('Volume of Trades in Each month')
sns.barplot(reliance_df.month, reliance_df.Volume);
# Out:
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### 6. What was the highest opening value of Reliance share ?

# %%
reliance_df_open = reliance_df.sort_values(by='Open', ascending=False).head(10)
reliance_df_open
# Out:
#           Date    Symbol Series  Prev Close     Open     High      Low  \
# 176 2020-09-14  RELIANCE     EQ     2319.75  2325.00  2360.00  2282.00
# 179 2020-09-17  RELIANCE     EQ     2324.55  2320.00  2333.70  2291.85
# 178 2020-09-16  RELIANCE     EQ     2318.85  2320.00  2369.35  2310.55
# 180 2020-09-18  RELIANCE     EQ     2298.75  2314.25  2319.45  2276.55
# 175 2020-11-09  RELIANCE     EQ     2314.00  2312.00  2337.85  2287.10
# 177 2020-09-15  RELIANCE     EQ     2302.55  2311.95  2325.75  2288.15
# 181 2020-09-21  RELIANCE     EQ     2305.70  2300.00  2336.00  2247.35
# 198 2020-10-15  RELIANCE     EQ     2287.50  2290.00  2290.00  2195.00
# 197 2020-10-14  RELIANCE     EQ     2280.70  2278.90  2304.00  2268.50
# 182 2020-09-22  RELIANCE     EQ     2255.85  2277.00  2277.00  2201.55
#
#         Last    Close     VWAP    Volume      Turnover  Trades  \
# 176  2296.25  2302.55  2323.57  20335480  4.725090e+15  450188
# ...

# %% [markdown]
# So the highest opening value was 2319.75 which was in the month of September.

# %% [markdown]
# ## Inferences and Conclusion
#
# In this notebook, i tried to analyse the data of Reliance Stocks 2020 which is my favourite topics personally. So i thought why not analyse one of the stocks of share market. I took help from the zero to pandas course provided from Jovian.ml, also pandas library and matplotlib,seaborn. This was my first analysing project and by doing this i am gettig a confidence to do more projects. I learned lot about the reliance stocks its highs, lows, opening prize, closing prize. I got lots of information from this dataset.

# %% [markdown]
# ## References and Future Work
#
# https://www.pandas.pydata.org, https://www.kaggle.com/, https://jovian.ai/outlink?url=https%3A%2F%2Fjovian.ml%2Fforum%2Ft%2Frecommended-datasets-for-course-project%2F11711

# %%
import jovian

# %%
jovian.commit(project='reliance-stocks2020-analysis', files='RELIANCE_2020.csv')
# Out:
# [jovian] Attempting to save notebook..
